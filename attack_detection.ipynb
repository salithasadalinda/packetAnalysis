# %%
from scapy.all import *
from scapy.all import rdpcap
from scapy.layers.inet import UDP
import pandas as pd
import matplotlib.pyplot as plt

packets = sniff(count=10)
# print(packets.summary())

# %%
# !pip install pandas
# !pip install pyx
# !pip install vpython
# !pip install cryptography
# Out:
# Collecting vpython
#   Downloading vpython-7.6.4.tar.gz (4.5 MB)
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB 217.9 kB/s eta 0:00:21
#      ---------------------------------------- 0.0/4.5 MB 217.9 kB/s eta 0:00:21
#       --------------------------------------- 0.1/4.5 MB 280.5 kB/s eta 0:00:16
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#       --------------------------------------- 0.1/4.5 MB 327.7 kB/s eta 0:00:14
#      - -------------------------------------- 0.2/4.5 MB 248.0 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/4.5 MB 248.0 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/4.5 MB 248.0 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/4.5 MB 218.5 kB/s eta 0:00:20
#      -- ------------------------------------- 0.2/4.5 MB 275.3 kB/s eta 0:00:16
#      -- ------------------------------------- 0.3/4.5 MB 321.5 kB/s eta 0:00:14
#      -- ------------------------------------- 0.3/4.5 MB 321.9 kB/s eta 0:00:14
#      -- ------------------------------------- 0.3/4.5 MB 333.2 kB/s eta 0:00:13
#      --- ------------------------------------ 0.4/4.5 MB 401.6 kB/s eta 0:00:11
#      ---- ----------------------------------- 0.5/4.5 MB 456.9 kB/s eta 0:00:09
#      ----- ---------------------------------- 0.6/4.5 MB 512.9 kB/s eta 0:00:08
#      ----- ---------------------------------- 0.6/4.5 MB 527.9 kB/s eta 0:00:08
#      ------ --------------------------------- 0.8/4.5 MB 637.8 kB/s eta 0:00:06
#      ------- -------------------------------- 0.9/4.5 MB 705.6 kB/s eta 0:00:06
#      -------- ------------------------------- 1.0/4.5 MB 759.4 kB/s eta 0:00:05
#      --------- ------------------------------ 1.1/4.5 MB 809.6 kB/s eta 0:00:05
#      ---------- ----------------------------- 1.2/4.5 MB 889.1 kB/s eta 0:00:04
#      ----------- ---------------------------- 1.3/4.5 MB 907.3 kB/s eta 0:00:04
#      ------------ --------------------------- 1.4/4.5 MB 948.0 kB/s eta 0:00:04
#      ------------- -------------------------- 1.5/4.5 MB 992.9 kB/s eta 0:00:04
#      ------------- -------------------------- 1.6/4.5 MB 995.8 kB/s eta 0:00:03
#      -------------- ------------------------- 1.6/4.5 MB 1.0 MB/s eta 0:00:03
#      --------------- ------------------------ 1.8/4.5 MB 1.1 MB/s eta 0:00:03
#      --------------- ------------------------ 1.8/4.5 MB 1.1 MB/s eta 0:00:03
#      --------------- ------------------------ 1.8/4.5 MB 1.1 MB/s eta 0:00:03
#      ---------------- ----------------------- 1.8/4.5 MB 1.0 MB/s eta 0:00:03
#      ---------------- ----------------------- 1.9/4.5 MB 1.0 MB/s eta 0:00:03
#      ----------------- ---------------------- 2.0/4.5 MB 1.0 MB/s eta 0:00:03
#      ----------------- ---------------------- 2.0/4.5 MB 1.0 MB/s eta 0:00:03
#      ------------------- -------------------- 2.1/4.5 MB 1.1 MB/s eta 0:00:03
#      ------------------- -------------------- 2.2/4.5 MB 1.1 MB/s eta 0:00:03
#      -------------------- ------------------- 2.3/4.5 MB 1.1 MB/s eta 0:00:03
#      -------------------- ------------------- 2.3/4.5 MB 1.1 MB/s eta 0:00:03
#      --------------------- ------------------ 2.5/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 2.5/4.5 MB 1.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.5 MB 1.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.5 MB 1.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------ --------------- 2.7/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------ --------------- 2.7/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------ --------------- 2.8/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------ --------------- 2.8/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 2.8/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 2.8/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 2.9/4.5 MB 1.1 MB/s eta 0:00:02
#      -------------------------- ------------- 2.9/4.5 MB 1.1 MB/s eta 0:00:02
#      -------------------------- ------------- 3.0/4.5 MB 1.1 MB/s eta 0:00:02
#      --------------------------- ------------ 3.1/4.5 MB 1.1 MB/s eta 0:00:02
#      --------------------------- ------------ 3.1/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 3.3/4.5 MB 995.6 kB/s eta 0:00:02
#      ----------------------------- ---------- 3.3/4.5 MB 993.9 kB/s eta 0:00:02
#      ----------------------------- ---------- 3.3/4.5 MB 990.8 kB/s eta 0:00:02
#      ----------------------------- ---------- 3.3/4.5 MB 972.5 kB/s eta 0:00:02
#      ------------------------------- -------- 3.5/4.5 MB 1.0 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 1.0 MB/s eta 0:00:01
#      ------------------------------- -------- 3.6/4.5 MB 1.0 MB/s eta 0:00:01
#      -------------------------------- ------- 3.6/4.5 MB 1.0 MB/s eta 0:00:01
#      -------------------------------- ------- 3.7/4.5 MB 1.0 MB/s eta 0:00:01
#      --------------------------------- ------ 3.8/4.5 MB 1.0 MB/s eta 0:00:01
#      --------------------------------- ------ 3.8/4.5 MB 1.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.0/4.5 MB 1.0 MB/s eta 0:00:01
#      ------------------------------------ --- 4.1/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 4.1/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 4.2/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 4.2/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.5 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.5 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------------- 4.5/4.5 MB 1.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jupyter (from vpython)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting jupyter-server-proxy (from vpython)
#   Downloading jupyter_server_proxy-4.1.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from vpython) (1.26.2)
# Requirement already satisfied: ipykernel in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from vpython) (6.27.1)
# Collecting autobahn<27,>=22.6.1 (from vpython)
#   Downloading autobahn-23.6.2.tar.gz (480 kB)
#      ---------------------------------------- 0.0/480.8 kB ? eta -:--:--
#      --- --------------------------------- 41.0/480.8 kB 960.0 kB/s eta 0:00:01
#      ----- ------------------------------- 71.7/480.8 kB 975.2 kB/s eta 0:00:01
#      ----------- -------------------------- 143.4/480.8 kB 1.2 MB/s eta 0:00:01
#      ---------------- --------------------- 204.8/480.8 kB 1.2 MB/s eta 0:00:01
#      -------------------- ----------------- 256.0/480.8 kB 1.2 MB/s eta 0:00:01
#      ----------------------------- -------- 368.6/480.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------- ----- 409.6/480.8 kB 1.3 MB/s eta 0:00:01
#      ------------------------------------ - 460.8/480.8 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 480.8/480.8 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting txaio>=21.2.1 (from autobahn<27,>=22.6.1->vpython)
#   Downloading txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# Collecting cryptography>=3.4.6 (from autobahn<27,>=22.6.1->vpython)
#   Downloading cryptography-41.0.7-cp37-abi3-win_amd64.whl.metadata (5.3 kB)
# Collecting hyperlink>=21.0.0 (from autobahn<27,>=22.6.1->vpython)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ---------------------------------------- 0.0/74.6 kB ? eta -:--:--
#      ---------------- ----------------------- 30.7/74.6 kB ? eta -:--:--
#      ---------------- ----------------------- 30.7/74.6 kB ? eta -:--:--
#      ------------------------------------ - 71.7/74.6 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 74.6/74.6 kB 515.2 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from autobahn<27,>=22.6.1->vpython) (65.5.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (1.5.8)
# Requirement already satisfied: packaging in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (23.2)
# Requirement already satisfied: psutil in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipykernel->vpython) (5.14.0)
# Requirement already satisfied: notebook in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter->vpython) (7.0.6)
# Collecting qtconsole (from jupyter->vpython)
#   Downloading qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter->vpython)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter->vpython) (7.12.0)
# Collecting ipywidgets (from jupyter->vpython)
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting aiohttp (from jupyter-server-proxy->vpython)
#   Downloading aiohttp-3.9.1-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: jupyter-server>=1.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server-proxy->vpython) (2.12.0)
# Collecting simpervisor>=1.0 (from jupyter-server-proxy->vpython)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (1.16.0)
# Requirement already satisfied: idna>=2.5 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from hyperlink>=21.0.0->autobahn<27,>=22.6.1->vpython) (3.6)
# Requirement already satisfied: decorator in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (0.6.3)
# Requirement already satisfied: colorama in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from ipython>=7.23.1->ipykernel->vpython) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->vpython) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->vpython) (4.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->vpython) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (4.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (23.1.0)
# Requirement already satisfied: jinja2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (3.1.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (5.9.2)
# Requirement already satisfied: overrides in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.19.0)
# Requirement already satisfied: pywinpty in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.0.12)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.18.0)
# Requirement already satisfied: websocket-client in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.7.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbconvert->jupyter->vpython) (1.2.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from aiohttp->jupyter-server-proxy->vpython) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->jupyter-server-proxy->vpython)
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->jupyter-server-proxy->vpython)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->jupyter-server-proxy->vpython)
#   Downloading frozenlist-1.4.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->jupyter-server-proxy->vpython)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets->jupyter->vpython)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets->jupyter->vpython)
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from notebook->jupyter->vpython) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from notebook->jupyter->vpython) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from notebook->jupyter->vpython) (0.2.3)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->vpython)
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->vpython) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->vpython) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->vpython) (0.8.3)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (4.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (6.0.1)
# Requirement already satisfied: referencing in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.31.1)
# Requirement already satisfied: rfc3339-validator in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.1.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->vpython) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->vpython) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (0.9.14)
# Requirement already satisfied: requests>=2.31 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (2.31.0)
# Requirement already satisfied: fastjsonschema in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from nbformat>=5.3.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.19.0)
# Requirement already satisfied: wcwidth in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->vpython) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->vpython) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->vpython) (2.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->vpython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->vpython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->vpython) (0.2.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.13.2)
# Requirement already satisfied: fqdn in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.4)
# Requirement already satisfied: uri-template in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->vpython) (2023.11.17)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\admin\desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.8.19.14)
# Downloading jupyter_server_proxy-4.1.0-py3-none-any.whl (33 kB)
# Downloading cryptography-41.0.7-cp37-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.7 MB 4.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.7 MB 4.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.7 MB 4.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.7 MB 3.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.7 MB 3.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.7 MB 3.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.7 MB 3.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.7 MB 3.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.1 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.7 MB 2.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.7 MB 2.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.7/2.7 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 2.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.7 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.7 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.7 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.4 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading aiohttp-3.9.1-cp311-cp311-win_amd64.whl (364 kB)
#    ---------------------------------------- 0.0/364.8 kB ? eta -:--:--
#    ------ --------------------------------- 61.4/364.8 kB 3.2 MB/s eta 0:00:01
#    ------------- -------------------------- 122.9/364.8 kB 1.8 MB/s eta 0:00:01
#    --------------------- ------------------ 194.6/364.8 kB 1.7 MB/s eta 0:00:01
#    ------------------------- -------------- 235.5/364.8 kB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 286.7/364.8 kB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 337.9/364.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 364.8/364.8 kB 1.2 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 1.2 MB/s eta 0:00:00
# Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.4 kB ? eta -:--:--
#    ------------- -------------------------- 41.0/123.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 123.4/123.4 kB 1.8 MB/s eta 0:00:00
# Downloading frozenlist-1.4.0-cp311-cp311-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/44.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/44.9 kB ? eta -:--:--
#    ------------------------------------ --- 41.0/44.9 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 44.9/44.9 kB 550.6 kB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.9 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/214.9 kB 991.0 kB/s eta 0:00:01
#    ---------------------- ----------------- 122.9/214.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 204.8/214.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 214.9/214.9 kB 1.5 MB/s eta 0:00:00
# Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.5 kB ? eta -:--:--
#    ----------------- ---------------------- 41.0/93.5 kB ? eta -:--:--
#    ----------------- ---------------------- 41.0/93.5 kB ? eta -:--:--
#    ----------------- ---------------------- 41.0/93.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/93.5 kB 585.1 kB/s eta 0:00:01
#    ---------------------------------------- 93.5/93.5 kB 486.9 kB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.3 MB 1.7 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.3 MB 1.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/2.3 MB 1.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.3 MB 1.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.3 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.3 MB 1.4 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.3 MB 1.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.6/2.3 MB 1.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.3 MB 1.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.7/2.3 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.7/2.3 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.7/2.3 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.3 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.3 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.3 MB 1.1 MB/s eta 0:00:02
#    --------------- ------------------------ 0.9/2.3 MB 1.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ------------------- -------------------- 1.1/2.3 MB 1.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.3 MB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.3 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.3 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.4/2.3 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.0/2.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.4 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.7 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/76.7 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 76.7/76.7 kB 1.1 MB/s eta 0:00:00
# Building wheels for collected packages: vpython, autobahn
#   Building wheel for vpython (pyproject.toml): started
#   Building wheel for vpython (pyproject.toml): finished with status 'done'
#   Created wheel for vpython: filename=vpython-7.6.4-cp311-cp311-win_amd64.whl size=3561524 sha256=2f6bc0640a3df8840f95d0f5b96ccb509d2481fc456d01bc465ca78d0a3ccfc0
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\64\19\80\2a712334328548878952d7184d3bb833ed105b2afcb2999735
#   Building wheel for autobahn (pyproject.toml): started
#   Building wheel for autobahn (pyproject.toml): finished with status 'done'
#   Created wheel for autobahn: filename=autobahn-23.6.2-py2.py3-none-any.whl size=666885 sha256=84c0710bfc2946c632fba6dd5840dd2a5636945d03872961e0445521bd626f83
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\2c\68\6a\d0d59a63751958c289282ac0f7d47ecdcbdf125cc385d83013
# Successfully built vpython autobahn
# Installing collected packages: widgetsnbextension, txaio, simpervisor, qtpy, multidict, jupyterlab-widgets, hyperlink, frozenlist, yarl, cryptography, aiosignal, autobahn, aiohttp, ipywidgets, qtconsole, jupyter-console, jupyter-server-proxy, jupyter, vpython
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 autobahn-23.6.2 cryptography-41.0.7 frozenlist-1.4.0 hyperlink-21.0.0 ipywidgets-8.1.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-server-proxy-4.1.0 jupyterlab-widgets-3.0.9 multidict-6.0.4 qtconsole-5.5.1 qtpy-2.4.1 simpervisor-1.0.0 txaio-23.1.1 vpython-7.6.4 widgetsnbextension-4.0.9 yarl-1.9.4

# %%
p=sniff(count=50)
p.plot(lambda x:len(x))

# %%
import pyx
p=IP()/ICMP()
p.pdfdump("test.pdf")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 3
#       1 import pyx
#       2 p=IP()/ICMP()
# ----> 3 p.pdfdump("test.pdf")
#
# File ~\Desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\Lib\site-packages\scapy\base_classes.py:474, in _CanvasDumpExtended.pdfdump(self, filename, **kargs)
#     472 from scapy.config import conf
#     473 from scapy.utils import get_temp_file, ContextManagerSubprocess
# --> 474 canvas = self.canvas_dump(**kargs)
#     475 if filename is None:
#     476     fname = get_temp_file(autoext=kargs.get("suffix", ".pdf"))
#
# File ~\Desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\Lib\site-packages\scapy\packet.py:787, in Packet.canvas_dump(self, layer_shift, rebuild)
#     784 def canvas_dump(self, layer_shift=0, rebuild=1):
#     785     # type: (int, int) -> pyx.canvas.canvas
#     786     if PYX == 0:
# --> 787         raise ImportError("PyX and its dependencies must be installed")
#     788     canvas = pyx.canvas.canvas()
#     789     if rebuild:
#
# ImportError: PyX and its dependencies must be installed

# %%
from scapy.all import rdpcap

# Read the pcap file
# p = rdpcap("myfile.pcap")

# Generate a jpg image of conversations
p.conversations(type="jpg", target="> test.jpg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 7
#       1 from scapy.all import rdpcap
#       3 # Read the pcap file
#       4 # p = rdpcap("myfile.pcap")
#       5
#       6 # Generate a jpg image of conversations
# ----> 7 p.conversations(type="jpg", target="> test.jpg")
#
# File ~\Desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\Lib\site-packages\scapy\plist.py:536, in _PacketList.conversations(self, getsrcdst, **kargs)
#     532     gr += '\t "%s" -> "%s" [label="%s"]\n' % (
#     533         s, d, ', '.join(str(x) for x in l) if isinstance(l, set) else l
#     534     )
#     535 gr += "}\n"
# --> 536 return do_graph(gr, **kargs)
#
# File ~\Desktop\python fun\nmap and wireshark tool\shark_attack_detector\attackdet_windows\Lib\site-packages\scapy\utils.py:864, in do_graph(graph, prog, format, target, type, string, options)
#     862 _, stderr = proc.communicate(bytes_encode(graph))
#     863 if proc.returncode != 0:
# --> 864     raise OSError(
#     865         "GraphViz call failed (is it installed?):\n" +
#     866         plain_str(stderr)
#     867     )
#     868 try:
#     869     target.close()
#
# OSError: GraphViz call failed (is it installed?):
# '""' is not recognized as an internal or external command,
# operable program or batch file.

# %%
a,u=traceroute(["www.python.org", "google.com","slashdot.org"])
a.trace3D()

# %%
enc=rdpcap("weplab-64bit-AA-managed.pcap")
enc.show()
enc[0]
conf.wepkey="AA\x00\x00\x00"
dec=Dot11PacketList(enc).toEthernet()
dec.show()
dec[0]
